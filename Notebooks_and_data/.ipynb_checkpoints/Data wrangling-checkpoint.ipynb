# %% [markdown]
# # Data wrangling and cleaning
# ***

# %% [markdown]
# To prepare the data for our models, we will wrangle and clean the data as necessary

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import preprocessing
import statsmodels.formula.api as sm

# %%
# define column header names in a list
names=["id", "date", "bedrooms", "bathrooms","sqft_living", "sqft_lot", "floors", "waterfront", "view", "condition", "grade", "sqft_above", "sqft_basement", "yr_built", "yr_renovated", "zipcode", "lat", "long", "sqft_living15", "sqft_lot15", "price"]

# %%
# Import data into pandas dataframe
df = pd.read_csv('regression_data.csv',names=names )

# %% [markdown]
# ***

# %%
# check if the import worked 
df.head()
# Out:
#            id      date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0  7129300520  10/13/14         3       1.00         1180      5650     1.0
# 1  6414100192   12/9/14         3       2.25         2570      7242     2.0
# 2  5631500400   2/25/15         2       1.00          770     10000     1.0
# 3  2487200875   12/9/14         4       3.00         1960      5000     1.0
# 4  1954400510   2/18/15         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3  ...        1180              0      1955
# 1           0     0          3  ...        2170            400      1951
# 2           0     0          3  ...         770              0      1933
# 3           0     0          5  ...        1050            910      1965
# 4           0     0          3  ...        1680              0      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0             0    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2             0    98028  47.7379 -122.233           2720        8062  180000
# 3             0    98136  47.5208 -122.393           1360        5000  604000
# 4             0    98074  47.6168 -122.045           1800        7503  510000
#
# [5 rows x 21 columns]

# %%
# we will directly drop the columns "ID", "lat", "long", "yr_built" and "date" 
# since they provide no value to our analysis according to the correlation matrix

df_drop=df.drop(['id', 'lat','long','yr_built','date'], axis = 1)

# %%
# check again if the columns were removed sucessfuly
df_drop.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 0          3      7        1180              0             0    98178
# 1          3      7        2170            400          1991    98125
# 2          3      6         770              0             0    98028
# 3          5      7        1050            910             0    98136
# 4          3      8        1680              0             0    98074
#
#    sqft_living15  sqft_lot15   price
# 0           1340        5650  221900
# 1           1690        7639  538000
# 2           2720        8062  180000
# 3           1360        5000  604000
# 4           1800        7503  510000

# %%
# define a quick function to convert the year renovated into a boolean value
# this is because we know from our real estate experience, that a renovation has an impact on the price, 
# but the year of renovation usually doesn't matter, only the fact that it got renovated

def boolean(x):
    if x == 0:
        n = 0
    elif x > 0:
        n = 1
    return n

# %%
# apply booloean function to yr_renovated colum
df_drop['yr_renovated']=df['yr_renovated'].apply(boolean)
# check if that worked by looking at the head again
df_drop.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 0          3      7        1180              0             0    98178
# 1          3      7        2170            400             1    98125
# 2          3      6         770              0             0    98028
# 3          5      7        1050            910             0    98136
# 4          3      8        1680              0             0    98074
#
#    sqft_living15  sqft_lot15   price
# 0           1340        5650  221900
# 1           1690        7639  538000
# 2           2720        8062  180000
# 3           1360        5000  604000
# 4           1800        7503  510000

# %% [markdown]
# ***

# %%
# look at the distribution of our variables
f, axes = plt.subplots(2, 2, figsize=(15, 15), sharex=False);
sns.histplot(x=df_drop["bedrooms"] , color="skyblue", ax=axes[0, 0]);
sns.histplot(x=df_drop["sqft_living"] , color="olive", ax=axes[0, 1]);
sns.histplot(x=df_drop["sqft_lot"], color="gold", ax=axes[1, 0]);
sns.histplot(x=df_drop["sqft_lot"] , color="teal", ax=axes[1, 1]);

# %% [markdown]
# We decided to get rid of the bedrooms outlier with 33 bedrooms and only 64k price'

# %%
#identify outlier in bedrooms column
i = df_drop[((df_drop.bedrooms > 10))]
i
# Out:
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 8748         11       3.00         3000      4960     2.0           0     0
# 15856        33       1.75         1620      6000     1.0           0     0
#
#        condition  grade  sqft_above  sqft_basement  yr_renovated  zipcode  \
# 8748           3      7        2400            600             1    98106
# 15856          5      7        1040            580             0    98103
#
#        sqft_living15  sqft_lot15   price
# 8748            1420        4960  520000
# 15856           1330        4700  640000

# %%
# drop outlier of bedrooms column
df_drop = df_drop.drop(df.index[15856])

# %%
# see if removal worked
sns.histplot(x=df_drop["bedrooms"]);

# %%
# look at the distribution of our variables 
f, axes = plt.subplots(2, 2, figsize=(15, 15), sharex=False);
sns.histplot(x=df_drop["floors"] , color="skyblue", ax=axes[0, 0]);
sns.histplot(x=df_drop["waterfront"] , color="olive", ax=axes[0, 1]);
sns.histplot(x=df_drop["view"], color="gold", ax=axes[1, 0]);
sns.histplot(x=df_drop["condition"] , color="teal", ax=axes[1, 1]);

# %% [markdown]
# No outlier removals for these columns

# %%
# look at the distribution of our variables
f, axes = plt.subplots(2, 2, figsize=(15, 15), sharex=False);
sns.histplot(x=df_drop["grade"] , color="skyblue", ax=axes[0, 0]);
sns.histplot(x=df_drop["sqft_above"] , color="olive", ax=axes[0, 1]);
sns.histplot(x=df_drop["sqft_basement"], color="gold", ax=axes[1, 0]);
sns.histplot(x=df_drop["yr_renovated"] , color="teal", ax=axes[1, 1]);

# %% [markdown]
# We probably wont use sqft_basement in our model since we have so many zero values

# %%
# look at the distribution of our variables
f, axes = plt.subplots(2, 2, figsize=(15, 15), sharex=False);
sns.histplot(x=df_drop["zipcode"] , color="skyblue", ax=axes[0, 0]);
sns.histplot(x=df_drop["sqft_living15"] , color="olive", ax=axes[0, 1]);
sns.histplot(x=df_drop["sqft_lot15"], color="gold", ax=axes[1, 0]);
sns.histplot(x=df_drop["price"] , color="teal", ax=axes[1, 1]);

# %% [markdown]
# ***

# %%
# normalizing the columns so the values get ditributed between 0 and 1
# we use preprocessing from the sklearn model to achieve this

#x = df_drop.values #returns a numpy array
#min_max_scaler = preprocessing.MinMaxScaler() # choose the model with which we are normalizin
#x_scaled = min_max_scaler.fit_transform(x) # create normalized values
#df_norm = pd.DataFrame(x_scaled) # create new normalized dataframe

# %%
# define headers for the normalized dataframe
#df_norm.columns =["bedrooms", "bathrooms","sqft_living", "sqft_lot", "floors", "waterfront", "view", "condition", "grade", "sqft_above", "sqft_basement", "yr_renovated", "zipcode", "sqft_living15",  "sqft_lot15", "price"]

# %%
# check if the normalization worked by looking at all distributions again and seeing if they are normalized
#df_norm.hist(figsize =(20,20));
#plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# checking the head to see if everything is still in place
df_norm.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       0.2   0.066667     0.061503  0.003108     0.0         0.0   0.0
# 1       0.2   0.233333     0.167046  0.004072     0.4         0.0   0.0
# 2       0.1   0.066667     0.030372  0.005743     0.0         0.0   0.0
# 3       0.3   0.333333     0.120729  0.002714     0.0         0.0   0.0
# 4       0.2   0.200000     0.099468  0.004579     0.0         0.0   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated   zipcode  \
# 0        0.5    0.4    0.089602       0.000000           0.0  0.893939
# 1        0.5    0.4    0.199115       0.082988           1.0  0.626263
# 2        0.5    0.3    0.044248       0.000000           0.0  0.136364
# 3        1.0    0.4    0.075221       0.188797           0.0  0.681818
# 4        0.5    0.5    0.144912       0.000000           0.0  0.368687
#
#    sqft_living15  sqft_lot15     price
# 0       0.161934    0.005742  0.018880
# 1       0.222165    0.008027  0.060352
# 2       0.399415    0.008513  0.013382
# 3       0.165376    0.004996  0.069011
# 4       0.241094    0.007871  0.056678

# %%
# Evaluate the first model with bedrooms + sqft_living + waterfront + view + condition + yr_renovated on X
import statsmodels.formula.api as sm
result = sm.ols(formula="price ~ bedrooms + sqft_living + waterfront + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept      -0.005435
# bedrooms       -0.068515
# sqft_living     0.502052
# waterfront      0.070354
# view            0.035197
# condition       0.023019
# yr_renovated    0.016012
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.569
# Method:                 Least Squares   F-statistic:                     4761.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43948.
# No. Observations:               21596   AIC:                        -8.788e+04
# Df Residuals:                   21589   BIC:                        -8.783e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0054      0.001     -5.395      0.000      -0.007      -0.003
# bedrooms        -0.0685      0.003    -22.927      0.000      -0.074      -0.063
# sqft_living      0.5021      0.004    124.360      0.000       0.494       0.510
# waterfront       0.0704      0.003     25.837      0.000       0.065       0.076
# view             0.0352      0.001     27.424      0.000       0.033       0.038
# condition        0.0230      0.001     17.233      0.000       0.020       0.026
# yr_renovated     0.0160      0.001     14.838      0.000       0.014       0.018
# ==============================================================================
# Omnibus:                    13006.167   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           439794.911
# Skew:                           2.344   Prob(JB):                         0.00
# Kurtosis:                      24.605   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate the second model with bathrooms + sqft_living + waterfront + view + condition + yr_renovated on X
# We use the statsmodels.formula.api library to check basic values of the model and see if it makes sense

result = sm.ols(formula="price ~ bathrooms + sqft_living + waterfront + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())

# seems like bedrooms is a bad variable to predict price with
# Out:
# Intercept      -0.013898
# bathrooms       0.007231
# sqft_living     0.438493
# waterfront      0.073243
# view            0.037950
# condition       0.020906
# yr_renovated    0.015967
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.559
# Model:                            OLS   Adj. R-squared:                  0.559
# Method:                 Least Squares   F-statistic:                     4565.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43690.
# No. Observations:               21596   AIC:                        -8.737e+04
# Df Residuals:                   21589   BIC:                        -8.731e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0139      0.001    -13.669      0.000      -0.016      -0.012
# bathrooms        0.0072      0.003      2.210      0.027       0.001       0.014
# sqft_living      0.4385      0.005     89.555      0.000       0.429       0.448
# waterfront       0.0732      0.003     26.606      0.000       0.068       0.079
# view             0.0379      0.001     29.326      0.000       0.035       0.040
# condition        0.0209      0.001     15.402      0.000       0.018       0.024
# yr_renovated     0.0160      0.001     14.620      0.000       0.014       0.018
# ==============================================================================
# Omnibus:                    13452.030   Durbin-Watson:                   1.979
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           491807.779
# Skew:                           2.439   Prob(JB):                         0.00
# Kurtosis:                      25.864   Cond. No.                         30.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with only bedrooms on X to check if it is really a bad variable to predict price with
result = sm.ols(formula="price ~ bedrooms", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept    0.020701
# bedrooms     0.168442
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.100
# Model:                            OLS   Adj. R-squared:                  0.100
# Method:                 Least Squares   F-statistic:                     2395.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 35981.
# No. Observations:               21596   AIC:                        -7.196e+04
# Df Residuals:                   21594   BIC:                        -7.194e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0207      0.001     23.693      0.000       0.019       0.022
# bedrooms       0.1684      0.003     48.937      0.000       0.162       0.175
# ==============================================================================
# Omnibus:                    18918.536   Durbin-Watson:                   1.962
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          1168858.729
# Skew:                           3.941   Prob(JB):                         0.00
# Kurtosis:                      38.169   Cond. No.                         11.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with bathrooms + sqft_living + waterfront + view + condition + yr_renovated on X


result = sm.ols(formula="price ~ bathrooms + bedrooms + sqft_living + waterfront + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept      -0.007095
# bathrooms       0.019484
# bedrooms       -0.071374
# sqft_living     0.482660
# waterfront      0.070358
# view            0.035317
# condition       0.024105
# yr_renovated    0.015950
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     4093.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43965.
# No. Observations:               21596   AIC:                        -8.791e+04
# Df Residuals:                   21588   BIC:                        -8.785e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0071      0.001     -6.793      0.000      -0.009      -0.005
# bathrooms        0.0195      0.003      5.955      0.000       0.013       0.026
# bedrooms        -0.0714      0.003    -23.600      0.000      -0.077      -0.065
# sqft_living      0.4827      0.005     93.104      0.000       0.472       0.493
# waterfront       0.0704      0.003     25.858      0.000       0.065       0.076
# view             0.0353      0.001     27.536      0.000       0.033       0.038
# condition        0.0241      0.001     17.894      0.000       0.021       0.027
# yr_renovated     0.0159      0.001     14.791      0.000       0.014       0.018
# ==============================================================================
# Omnibus:                    13071.419   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           444735.144
# Skew:                           2.359   Prob(JB):                         0.00
# Kurtosis:                      24.725   Cond. No.                         32.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with bathrooms + sqft_lot + waterfront + view + condition + yr_renovated on X
result = sm.ols(formula="price ~ bathrooms + sqft_lot + waterfront + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept      -0.008589
# bathrooms       0.224347
# sqft_lot        0.051887
# waterfront      0.072519
# view            0.060826
# condition       0.025945
# yr_renovated    0.016745
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.396
# Model:                            OLS   Adj. R-squared:                  0.396
# Method:                 Least Squares   F-statistic:                     2361.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 40292.
# No. Observations:               21596   AIC:                        -8.057e+04
# Df Residuals:                   21589   BIC:                        -8.051e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0086      0.001     -7.226      0.000      -0.011      -0.006
# bathrooms        0.2243      0.003     87.502      0.000       0.219       0.229
# sqft_lot         0.0519      0.010      5.077      0.000       0.032       0.072
# waterfront       0.0725      0.003     22.507      0.000       0.066       0.079
# view             0.0608      0.001     40.929      0.000       0.058       0.064
# condition        0.0259      0.002     16.345      0.000       0.023       0.029
# yr_renovated     0.0167      0.001     13.101      0.000       0.014       0.019
# ==============================================================================
# Omnibus:                    15757.383   Durbin-Watson:                   1.965
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           772087.156
# Skew:                           3.000   Prob(JB):                         0.00
# Kurtosis:                      31.671   Cond. No.                         47.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with bathrooms + bedrooms + sqft_living + view + condition + yr_renovated on X
result = sm.ols(formula="price ~ bedrooms + sqft_living + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept      -0.005186
# bedrooms       -0.072031
# sqft_living     0.503774
# view            0.047752
# condition       0.023169
# yr_renovated    0.017594
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.556
# Model:                            OLS   Adj. R-squared:                  0.556
# Method:                 Least Squares   F-statistic:                     5413.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43619.
# No. Observations:               21596   AIC:                        -8.723e+04
# Df Residuals:                   21590   BIC:                        -8.718e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0052      0.001     -5.070      0.000      -0.007      -0.003
# bedrooms        -0.0720      0.003    -23.765      0.000      -0.078      -0.066
# sqft_living      0.5038      0.004    122.920      0.000       0.496       0.512
# view             0.0478      0.001     39.592      0.000       0.045       0.050
# condition        0.0232      0.001     17.084      0.000       0.021       0.026
# yr_renovated     0.0176      0.001     16.083      0.000       0.015       0.020
# ==============================================================================
# Omnibus:                    13727.050   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           493906.799
# Skew:                           2.520   Prob(JB):                         0.00
# Kurtosis:                      25.880   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with  bedrooms + sqft_living + view + condition on X
result = sm.ols(formula="price ~ bedrooms + sqft_living + view + condition", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept     -0.003856
# bedrooms      -0.072115
# sqft_living    0.504991
# view           0.049607
# condition      0.021787
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.551
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     6623.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43490.
# No. Observations:               21596   AIC:                        -8.697e+04
# Df Residuals:                   21591   BIC:                        -8.693e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.0039      0.001     -3.760      0.000      -0.006      -0.002
# bedrooms       -0.0721      0.003    -23.651      0.000      -0.078      -0.066
# sqft_living     0.5050      0.004    122.509      0.000       0.497       0.513
# view            0.0496      0.001     41.075      0.000       0.047       0.052
# condition       0.0218      0.001     16.002      0.000       0.019       0.024
# ==============================================================================
# Omnibus:                    13813.112   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           503009.424
# Skew:                           2.540   Prob(JB):                         0.00
# Kurtosis:                      26.091   Cond. No.                         25.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Evaluate another model with bedrooms + sqft_living + condition on X

result = sm.ols(formula="price ~ bedrooms + sqft_living + condition", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept     -0.006562
# bedrooms      -0.086816
# sqft_living    0.555695
# condition      0.025960
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.516
# Method:                 Least Squares   F-statistic:                     7669.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 42678.
# No. Observations:               21596   AIC:                        -8.535e+04
# Df Residuals:                   21592   BIC:                        -8.532e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept      -0.0066      0.001     -6.176      0.000      -0.009      -0.004
# bedrooms       -0.0868      0.003    -27.613      0.000      -0.093      -0.081
# sqft_living     0.5557      0.004    136.081      0.000       0.548       0.564
# condition       0.0260      0.001     18.415      0.000       0.023       0.029
# ==============================================================================
# Omnibus:                    14274.795   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           485668.826
# Skew:                           2.694   Prob(JB):                         0.00
# Kurtosis:                      25.599   Cond. No.                         24.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
result = sm.ols(formula="price ~ bathrooms + bedrooms + sqft_living + waterfront + view + condition + yr_renovated", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept      -0.007095
# bathrooms       0.019484
# bedrooms       -0.071374
# sqft_living     0.482660
# waterfront      0.070358
# view            0.035317
# condition       0.024105
# yr_renovated    0.015950
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.570
# Model:                            OLS   Adj. R-squared:                  0.570
# Method:                 Least Squares   F-statistic:                     4093.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 43965.
# No. Observations:               21596   AIC:                        -8.791e+04
# Df Residuals:                   21588   BIC:                        -8.785e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept       -0.0071      0.001     -6.793      0.000      -0.009      -0.005
# bathrooms        0.0195      0.003      5.955      0.000       0.013       0.026
# bedrooms        -0.0714      0.003    -23.600      0.000      -0.077      -0.065
# sqft_living      0.4827      0.005     93.104      0.000       0.472       0.493
# waterfront       0.0704      0.003     25.858      0.000       0.065       0.076
# view             0.0353      0.001     27.536      0.000       0.033       0.038
# condition        0.0241      0.001     17.894      0.000       0.021       0.027
# yr_renovated     0.0159      0.001     14.791      0.000       0.014       0.018
# ==============================================================================
# Omnibus:                    13071.419   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           444735.144
# Skew:                           2.359   Prob(JB):                         0.00
# Kurtosis:                      24.725   Cond. No.                         32.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
df_norm.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0       0.2   0.066667     0.061503  0.003108     0.0         0.0   0.0
# 1       0.2   0.233333     0.167046  0.004072     0.4         0.0   0.0
# 2       0.1   0.066667     0.030372  0.005743     0.0         0.0   0.0
# 3       0.3   0.333333     0.120729  0.002714     0.0         0.0   0.0
# 4       0.2   0.200000     0.099468  0.004579     0.0         0.0   0.0
#
#    condition  grade  sqft_above  sqft_basement  yr_renovated   zipcode  \
# 0        0.5    0.4    0.089602       0.000000           0.0  0.893939
# 1        0.5    0.4    0.199115       0.082988           1.0  0.626263
# 2        0.5    0.3    0.044248       0.000000           0.0  0.136364
# 3        1.0    0.4    0.075221       0.188797           0.0  0.681818
# 4        0.5    0.5    0.144912       0.000000           0.0  0.368687
#
#    sqft_living15  sqft_lot15     price
# 0       0.161934    0.005742  0.018880
# 1       0.222165    0.008027  0.060352
# 2       0.399415    0.008513  0.013382
# 3       0.165376    0.004996  0.069011
# 4       0.241094    0.007871  0.056678

# %%
result = sm.ols(formula="price ~ bedrooms + bathrooms + sqft_living + sqft_lot + floors+ waterfront + view + condition + grade + sqft_above + sqft_basement + yr_renovated + zipcode + yr_renovated + sqft_living15 + sqft_lot15", data=df_norm).fit()
print(result.params)
print(result.summary())
# Out:
# Intercept       -0.060279
# bedrooms        -0.047486
# bathrooms       -0.009366
# sqft_living      0.122868
# sqft_lot         0.011609
# floors          -0.002923
# waterfront       0.074625
# view             0.027182
# condition        0.031187
# grade            0.133629
# sqft_above       0.134977
# sqft_basement    0.082568
# yr_renovated     0.018271
# zipcode          0.011817
# sqft_living15    0.018777
# sqft_lot15      -0.081348
# dtype: float64
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  price   R-squared:                       0.618
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                     2491.
# Date:                Mon, 19 Apr 2021   Prob (F-statistic):               0.00
# Time:                        14:21:09   Log-Likelihood:                 45229.
# No. Observations:               21596   AIC:                        -9.043e+04
# Df Residuals:                   21581   BIC:                        -9.031e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        -0.0603      0.001    -40.491      0.000      -0.063      -0.057
# bedrooms         -0.0475      0.003    -16.235      0.000      -0.053      -0.042
# bathrooms        -0.0094      0.003     -2.736      0.006      -0.016      -0.003
# sqft_living       0.1229      0.002     49.622      0.000       0.118       0.128
# sqft_lot          0.0116      0.012      0.994      0.320      -0.011       0.035
# floors           -0.0029      0.001     -2.247      0.025      -0.005      -0.000
# waterfront        0.0746      0.003     29.022      0.000       0.070       0.080
# view              0.0272      0.001     21.612      0.000       0.025       0.030
# condition         0.0312      0.001     23.702      0.000       0.029       0.034
# grade             0.1336      0.003     43.379      0.000       0.128       0.140
# sqft_above        0.1350      0.003     41.470      0.000       0.129       0.141
# sqft_basement     0.0826      0.003     31.755      0.000       0.077       0.088
# yr_renovated      0.0183      0.001     17.859      0.000       0.016       0.020
# zipcode           0.0118      0.001     14.475      0.000       0.010       0.013
# sqft_living15     0.0188      0.003      6.409      0.000       0.013       0.025
# sqft_lot15       -0.0813      0.009     -8.638      0.000      -0.100      -0.063
# ==============================================================================
# Omnibus:                    15843.767   Durbin-Watson:                   1.984
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           990774.074
# Skew:                           2.941   Prob(JB):                         0.00
# Kurtosis:                      35.657   Cond. No.                     5.10e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.68e-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# ## Decisions for the Model:
# ***
# - We will drop the zipcodes, since it provides no value to our model - we might evaluate this is an second approach
# - we will also not include bedrooms in our model, since the results are ambigous
# - There are some multiple values in the data. We will keep them, since the development of price is interesting to pay attention to
# - We will test models with resampling of the waterfront and see if that increases our precision
# - We will test models with resampling of the yr_renovated and see if that increases our precision
# - we will only include one sqft measure per appraoch since they all are highly correlated to another

# %%
# prepare our dataframe for export by dropping zipcode column
df_norm = df_norm.drop(['zipcode','sqft_lot', 'sqft_above', 'sqft_basement', 'sqft_living15', 'sqft_lot15'], axis = 1) 
df_norm.head()
# Out:
#    bedrooms  bathrooms  sqft_living  floors  waterfront  view  condition  \
# 0       0.2   0.066667     0.061503     0.0         0.0   0.0        0.5
# 1       0.2   0.233333     0.167046     0.4         0.0   0.0        0.5
# 2       0.1   0.066667     0.030372     0.0         0.0   0.0        0.5
# 3       0.3   0.333333     0.120729     0.0         0.0   0.0        1.0
# 4       0.2   0.200000     0.099468     0.0         0.0   0.0        0.5
#
#    grade  yr_renovated     price
# 0    0.4           0.0  0.018880
# 1    0.4           1.0  0.060352
# 2    0.3           0.0  0.013382
# 3    0.4           0.0  0.069011
# 4    0.5           0.0  0.056678

# %%
# export to csv
df_norm.to_csv('model.csv')
